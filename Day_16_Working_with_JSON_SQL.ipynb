# %% [markdown]
# <a href="https://colab.research.google.com/github/iamdeepti25/100-Days-of-ML/blob/main/Day_16_Working_with_JSON_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #JSON -> JavaScript On Notation
#
# JSON is universal, meaning almost every programming language has JSON, and can parse(use) it
#
# Main use case of JSON is in Calling APIs. APIs return the request with JSON data.

# %%
import pandas as pd

# %% [markdown]
# for parameters of read_json read documentation -
#
# https://pandas.pydata.org/docs/reference/api/pandas.read_json.html

# %% [markdown]
# check out the data set first here - https://www.kaggle.com/datasets/busielmorley/worldcities-pop-lang-rank-sql-create-tbls

# %%
pd.read_json('train.json') #for parameters read documentation
#key value pair
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json('https://api.exchangerate-api.com/v4/latest/INR') #from URLs
# Out:
#                              provider  \
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ANG  https://www.exchangerate-api.com
# ..                                ...
# XPF  https://www.exchangerate-api.com
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ANG  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# XPF  https://www.exchangerate-api.com/docs/free
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ...

# %% [markdown]
# #SQL -> Structured Query Language

# %% [markdown]
# https://www.youtube.com/watch?v=fFwRC-fapIU&list=PLKnIA16_Rmvbr7zKYQuBfsVkjoLcJgxHH&index=16&t=26s&ab_channel=CampusX

# %%
# !pip install mysql.connector
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 31.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp310-cp310-linux_x86_64.whl size=247953 sha256=a5f2bc4bff56a26d4e6763ac1e7886fed5f4aa5e23e59e368be783eefd10c25b
#   Stored in directory: /root/.cache/pip/wheels/76/48/9b/da67ff1a18fe8e9d428f9b1a177716d4a7d363d2bbe83bf6cf
# Successfully built mysql.connector
# ...

# %%
conn = mysql.connector.connect(host='localhost',user='root',password='',database='world')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b6dab4bb7424> in <cell line: 1>()
# ----> 1 conn = mysql.connector.connect(host='localhost',user='root',password='',database='world')
#
# NameError: name 'mysql' is not defined

# %%
import requests

url = "https://api.themoviedb.org/3/account/21194738/rated/movies?language=en-US&page=1&sort_by=created_at.asc"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer 19b30a4b579d51eafcd64a01502b3260"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"status_code":7,"status_message":"Invalid API key: You must be granted a valid key.","success":false}
